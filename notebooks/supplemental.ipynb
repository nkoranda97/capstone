# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../")

# %%
import pylidc as pl
import configparser
import matplotlib.cm
import matplotlib as mpl
from scripts.supplemental import generate_simple_video, visualize_union_logic

if not hasattr(configparser, "SafeConfigParser"):
    configparser.SafeConfigParser = configparser.ConfigParser
import numpy as np

if not hasattr(np, "int"):
    np.int = int

if not hasattr(np, "float"):
    np.float = float

if not hasattr(matplotlib.cm, "cmap_d"):
    matplotlib.cm.cmap_d = mpl.colormaps
# Out:
# /home/nkoranda/Projects/capstone/.venv/lib/python3.13/site-packages/pylidc/__init__.py:27: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as _pr

# %%
scan = pl.query(pl.Scan).first()
generate_simple_video(scan)
# Out:
# Processing Scan ID: 1 (1.3.6.1.4.1.14519.5.2.1.6279.6001.303494235102183795724852353824)
# Loading scan volume...
# Loading dicom files ... This may take a moment.
# Volume loaded. Shape: (512, 512, 87). Total slices: 87
# Created temp folder: temp_scan_slices
# Processing 87 slices...
# ...
# Extracting Images: 100%|██████████| 87/87 [00:00<00:00, 114.28it/s]
# Compiling 87 frames into GIF: scan_animation.gif...
#
# ✅ SUCCESS: Animation saved as: scan_animation.gif
# Cleaned up temporary folder: temp_scan_slices

# %%
ann = pl.query(pl.Annotation).first()
ann.visualize_in_3d(cmap="viridis")
# Out:
# Patched matplotlib.cm.cmap_d for pylidc compatibility.

# %%
scans = pl.query(pl.Scan).all()
visualize_union_logic(scans)
# Out:
# Searching for a nodule with disagreement...
# Loading dicom files ... This may take a moment.
# Loading dicom files ... This may take a moment.
# Visualization for Patient: LIDC-IDRI-0315
# Slice Z-Index: 67
# Union Box Width: 23px, Height: 31px
